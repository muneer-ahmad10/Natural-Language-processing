# %%
import torch
import torch.nn as nn

# %%
texts = [
    "i love this movie",
    "this is amazing",
    "i hate this",
    "this is terrible"
]

labels = [1, 1, 0, 0]

# %%
from collections import Counter

# %%
#Build Vocab
all_words=' '.join(texts).split()
vocab={word:i + 1 for i, word in enumerate(set(all_words))}

def decode(sentence):
  return [vocab[w] for w in sentence.split()]

# %%
' '.join(texts).split()
# Out:
# ['i',
#  'love',
#  'this',
#  'movie',
#  'this',
#  'is',
#  'amazing',
#  'i',
#  'hate',
#  'this',
#  'this',
#  'is',
#  'terrible']

# %%
{word:i+1 for i, word in enumerate(set(all_words))}
# Out:
# {'movie': 1,
#  'is': 2,
#  'amazing': 3,
#  'terrible': 4,
#  'i': 5,
#  'love': 6,
#  'hate': 7,
#  'this': 8}

# %%
from collections import Counter

# %%
texts
# Out:
# ['i love this movie', 'this is amazing', 'i hate this', 'this is terrible']

# %%
all_words=' '.join(texts).split()

# %%
all_words
# Out:
# ['i',
#  'love',
#  'this',
#  'movie',
#  'this',
#  'is',
#  'amazing',
#  'i',
#  'hate',
#  'this',
#  'this',
#  'is',
#  'terrible']

# %%
vocab={words:i+1 for i ,words in enumerate(set(all_words))}

# %%
def decode(sentence):
  return [vocab[w] for w in sentence.split()]

# %%
vocab
# Out:
# {'love': 1,
#  'hate': 2,
#  'this': 3,
#  'movie': 4,
#  'is': 5,
#  'amazing': 6,
#  'terrible': 7,
#  'i': 8}

# %%
decode('i love this movie')
# Out:
# [8, 1, 3, 4]
