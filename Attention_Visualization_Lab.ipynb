# %% [markdown]
# <a href="https://colab.research.google.com/github/muneer-ahmad10/Natural-Language-processing/blob/main/Attention_Visualization_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# "bank" — notice it strongly attends to "flooded", which is exactly how the model figures out this is a river bank and not a financial bank. This is the entire point of attention visualization: reading those weights tells you why the model made its prediction. Now the math behind every cell in that heatmap:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q asks "what am I looking for?", K says "here is what I contain", V says "here is what I'll give you if you pick me." The dot product Q·Kᵀ measures how well each key matches the query — that score, after softmax, controls how much of each V gets mixed into the output.
