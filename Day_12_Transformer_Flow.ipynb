# %% [markdown]
# <a href="https://colab.research.google.com/github/muneer-ahmad10/Natural-Language-processing/blob/main/Day_12_Transformer_Flow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Complete Transformer Flow**
#
# Sentence
# ↓
# Tokenization
# ↓
# Vocabulary IDs
# ↓
# Embedding Layer
# ↓
# Positional Encoding
# ↓
# Multi Head Attention
# ↓
# Feed Forward Network
# ↓
# Linear Layer
# ↓
# Softmax
# ↓
# Next Word Prediction

# %%
#Example SEntence

sentence = "i love ai"

# %%
#Vocabulary
vocab = {
    "i":0,
    "love":1,
    "ai":2
}

# %%
#Convert words into IDs:

tokens = [0,1,2]

# %%
# Embedding
0
1
2

# these numbers have no meaning
# Out:
# 2

# %%
#code
import torch
import torch.nn as nn

embedding = nn.Embedding(
    num_embeddings=3,
    embedding_dim=4
)

tokens = torch.tensor([0,1,2])

embedded = embedding(tokens)

print(embedded.shape)
# Out:
# torch.Size([3, 4])

# %%
#Positional Encoding
